# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## João Pedro Montefeltro Junqueira Meirelles
# ___

# %% [markdown]
# ## Divesidade alimentar brasileira

# %% [markdown]
# ___
# ## Introdução
#
# Nesse projeto pretendo analisar com base na PNAD de 2009, a variação de alimentação entre os ESTADOS brasileiros.

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\1513 IRON\Desktop\insper\semestre 2\CD\Projeto1\CD

# %%
#Se usar o arquivo descompactado
#pd.read_csv('DOM2015.csv',sep=',')
planilha2009 = pd.read_csv('DOM2009csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
defe = pd.DataFrame()

defe['UF'] = planilha2009[planilha2009.UF>2].UF

defe['medo alimentar'] = planilha2009.V2103

defe['sem dinheiro'] = planilha2009.V2107

defe['deficiência alimentar'] = planilha2009.V2109

defe['sem alimento'] = planilha2009.V2105

defe['tipo residencial'] = planilha2009.V4105

defe_no = defe.dropna()

# %%
#filtragem]
defe.loc[planilha2009.UF>10,'UF'] = 'Norte'
defe.loc[planilha2009.UF>20,'UF'] = 'Nordeste'
defe.loc[planilha2009.UF>30,'UF'] = 'Sudeste'
defe.loc[planilha2009.UF>40,'UF'] = 'Sul'
defe.loc[planilha2009.UF>50,'UF'] = 'Centro-Oeste'
defe.loc[planilha2009.UF==53,'UF'] = 'Distrito Ferderal'

defe.loc[planilha2009.V2103 == 1,'medo alimentar'] = 'sim'
defe.loc[planilha2009.V2103 == 3,'medo alimentar'] = 'não'

defe.loc[planilha2009.V2107 == 1,'sem dinheiro'] = 'sim'
defe.loc[planilha2009.V2107 == 3,'sem dinheiro'] = 'não'

defe.loc[planilha2009.V2109 == 1,'deficiência alimentar'] = 'sim'
defe.loc[planilha2009.V2109 == 3,'deficiência alimentar'] = 'não'

defe.loc[planilha2009.V2105 == 1,'sem alimento'] = 'sim'
defe.loc[planilha2009.V2105 == 3,'sem alimento'] = 'não'

defe.loc[planilha2009.V4105 == 1,'tipo residencial'] = 'sim'
defe.loc[planilha2009.V4105 == 3,'tipo residencial'] = 'não'

defe = defe.dropna()

# %%
#Sem dinheiro para comida em diferentes regiões
defe['medo alimentar'].value_counts().plot(kind='pie',autopct="%0.2f", legend=True)
plt.show()

# %%
defe['sem dinheiro'].value_counts().plot(kind='pie',autopct="%0.2f",title = 'sem dinheiro para alimentação', legend = True)

# %%
plot = defe['sem alimento'].value_counts().plot(kind='pie',autopct="%0.2f",title = 'sem alimento', legend = False)
plt.show()
plot = defe['medo alimentar'].value_counts().plot(kind='pie',autopct="%0.2f",title = 'medo alimentar', legend=False)

# %%
cross = pd.crosstab(defe['sem alimento'],defe['medo alimentar'])
cross_sim = cross.iloc[1:2,:]
plot = cross_sim.plot(kind='bar',title = 'Pessaos medo alimentar com ou sem alimento',legend = True)
plt.show()
cross_sim
# Out:
# medo alimentar   não    sim
# sem alimento
# sim             1591  19452

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!

# %%
defe
# Out:
#                        UF medo alimentar sem dinheiro deficiência alimentar  \
# 2                   Norte            sim          sim                   sim
# 3                   Norte            não          não                   não
# 4                   Norte            não          não                   não
# 6                   Norte            não          não                   não
# 7                   Norte            não          não                   não
# 8                   Norte            sim          sim                   sim
# 9                   Norte            sim          não                   não
# 10                  Norte            sim          sim                   sim
# 12                  Norte            não          não                   não
# 13                  Norte            não          não                   não
# 14                  Norte            sim          não                   não
# ...

# %%
defe_no
# Out:
#         UF  medo alimentar  sem dinheiro  deficiência alimentar  sem alimento  \
# 2       11             1.0           1.0                    1.0           1.0
# 3       11             3.0           3.0                    3.0           3.0
# 4       11             3.0           3.0                    3.0           3.0
# 6       11             3.0           3.0                    3.0           3.0
# 7       11             3.0           3.0                    3.0           3.0
# 8       11             1.0           1.0                    1.0           1.0
# 9       11             1.0           3.0                    3.0           3.0
# 10      11             1.0           1.0                    1.0           1.0
# 12      11             3.0           3.0                    3.0           3.0
# 13      11             3.0           3.0                    3.0           3.0
# 14      11             1.0           3.0                    3.0           3.0
# ...
