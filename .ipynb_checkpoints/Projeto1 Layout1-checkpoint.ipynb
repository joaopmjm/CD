# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## COLOQUE AQUI SEU NOME
# ___

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\1513 IRON\Desktop\insper\semestre 2\CD\Projeto1\CD

# %%
#Se usar o arquivo descompactado
#pd.read_csv('DOM2015.csv',sep=',')
planilha2009 = pd.read_csv('DOM2009csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
defe = pd.DataFrame()

defe['medo alimentar'] = planilha2009.V2103

defe['UF'] = planilha2009[planilha2009.UF>2].UF

defe['sem dinheiro'] = planilha2009.V2107

defe['deficiência alimentar'] = planilha2009.V2109

defe['sem alimento'] = planilha2009.V2105

defe['tipo residencial'] = planilha2009.V4105

defe_no = defe.dropna()

# %%
#filtragem]
defe.loc[planilha2009.UF>10,'UF'] = 'Norte'
defe.loc[planilha2009.UF>20,'UF'] = 'Nordeste'
defe.loc[planilha2009.UF>30,'UF'] = 'Sudeste'
defe.loc[planilha2009.UF>40,'UF'] = 'Sul'
defe.loc[planilha2009.UF>50,'UF'] = 'Centro-Oeste'
defe.loc[planilha2009.UF==53,'UF'] = 'Distrito Ferderal'

defe.loc[planilha2009.V2103 == 1,'medo alimentar'] = 'sim'
defe.loc[planilha2009.V2103 == 3,'medo alimentar'] = 'não'

defe.loc[planilha2009.V2107 == 1,'sem dinheiro'] = 'sim'
defe.loc[planilha2009.V2107 == 3,'sem dinheiro'] = 'não'

defe.loc[planilha2009.V2109 == 1,'deficiência alimentar'] = 'sim'
defe.loc[planilha2009.V2109 == 3,'deficiência alimentar'] = 'não'

defe.loc[planilha2009.V2105 == 1,'sem alimento'] = 'sim'
defe.loc[planilha2009.V2105 == 3,'sem alimento'] = 'não'

defe.loc[planilha2009.V4105 == 1,'tipo residencial'] = 'sim'
defe.loc[planilha2009.V4105 == 3,'tipo residencial'] = 'não'

defe = defe.dropna()

# %%
#Sem dinheiro para comida em diferentes regiões
defe['medo alimentar'].value_counts().plot(kind='pie', legend=True)
plt.show()

# %%
defe['sem dinheiro'].value_counts().plot(kind='pie',title = 'sem dinheiro para alimentação', legend = True)

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!

# %%
defe
# Out:
#        medo alimentar                 UF sem dinheiro deficiência alimentar  \
# 2                 sim              Norte          sim                   sim
# 3                 não              Norte          não                   não
# 4                 não              Norte          não                   não
# 6                 não              Norte          não                   não
# 7                 não              Norte          não                   não
# 8                 sim              Norte          sim                   sim
# 9                 sim              Norte          não                   não
# 10                sim              Norte          sim                   sim
# 12                não              Norte          não                   não
# 13                não              Norte          não                   não
# 14                sim              Norte          não                   não
# 15                não              Norte          não                   não
# 16                não              Norte          não                   não
# 18                não              Norte          não                   não
# 19                sim              Norte          não                   sim
# 21                não              Norte          não                   não
# 22                não              Norte          não                   não
# 23                não              Norte          não                   não
# 24                não              Norte          não                   não
# 25                sim              Norte          sim                   sim
# 26                não              Norte          não                   não
# 27                sim              Norte          sim                   sim
# 29                sim              Norte          sim                   sim
# 30                sim              Norte          sim                   sim
# 31                não              Norte          sim                   sim
# 33                sim              Norte          não                   não
# 37                não              Norte          não                   não
# 39                não              Norte          não                   não
# 40                não              Norte          não                   não
# 41                não              Norte          não                   não
# ...               ...                ...          ...                   ...
# 153787            não  Distrito Ferderal          não                   não
# 153789            não  Distrito Ferderal          não                   não
# 153790            não  Distrito Ferderal          não                   não
# 153791            não  Distrito Ferderal          não                   não
# 153792            não  Distrito Ferderal          não                   não
# 153794            não  Distrito Ferderal          não                   não
# 153795            não  Distrito Ferderal          não                   não
# 153796            não  Distrito Ferderal          não                   não
# 153797            não  Distrito Ferderal          não                   não
# 153798            não  Distrito Ferderal          não                   não
# 153799            não  Distrito Ferderal          não                   não
# 153800            não  Distrito Ferderal          não                   não
# 153801            não  Distrito Ferderal          não                   não
# 153802            não  Distrito Ferderal          não                   não
# 153807            não  Distrito Ferderal          não                   não
# 153808            não  Distrito Ferderal          não                   não
# 153809            não  Distrito Ferderal          não                   não
# 153810            sim  Distrito Ferderal          não                   sim
# 153811            não  Distrito Ferderal          não                   não
# 153815            não  Distrito Ferderal          não                   não
# 153817            não  Distrito Ferderal          não                   não
# 153818            não  Distrito Ferderal          não                   não
# 153819            não  Distrito Ferderal          não                   não
# 153823            não  Distrito Ferderal          não                   não
# 153830            não  Distrito Ferderal          não                   não
# 153831            não  Distrito Ferderal          não                   não
# 153832            não  Distrito Ferderal          não                   não
# 153834            não  Distrito Ferderal          não                   não
# 153835            não  Distrito Ferderal          não                   não
# 153836            não  Distrito Ferderal          não                   não
#
#        sem alimento tipo residencial
# 2               sim              sim
# 3               não              sim
# 4               não              sim
# 6               não              sim
# 7               não              sim
# 8               sim              sim
# 9               não              sim
# 10              sim              sim
# 12              não              sim
# 13              não              sim
# 14              não              sim
# 15              não              sim
# 16              não              sim
# 18              não              sim
# 19              sim              sim
# 21              não              sim
# 22              não              sim
# 23              não              sim
# 24              não              sim
# 25              sim              sim
# 26              não              sim
# 27              sim              sim
# 29              sim              sim
# 30              sim              sim
# 31              sim              sim
# 33              não              sim
# 37              não              sim
# 39              não              sim
# 40              não              sim
# 41              não              sim
# ...             ...              ...
# 153787          não                2
# 153789          não                2
# 153790          não                2
# 153791          não                2
# 153792          não                2
# 153794          não                2
# 153795          não                2
# 153796          não              sim
# 153797          não              sim
# 153798          não              sim
# 153799          não                2
# 153800          não              sim
# 153801          não              sim
# 153802          não              sim
# 153807          não              sim
# 153808          não              sim
# 153809          não              sim
# 153810          não              sim
# 153811          não                2
# 153815          não                2
# 153817          não                2
# 153818          não                2
# 153819          não                2
# 153823          não                2
# 153830          não                2
# 153831          não                2
# 153832          não                2
# 153834          não                2
# 153835          não                2
# 153836          não                2
#
# [121163 rows x 6 columns]

# %%
defe_no
# Out:
#         medo alimentar  UF  sem dinheiro  deficiência alimentar  sem alimento  \
# 2                  1.0  11           1.0                    1.0           1.0
# 3                  3.0  11           3.0                    3.0           3.0
# 4                  3.0  11           3.0                    3.0           3.0
# 6                  3.0  11           3.0                    3.0           3.0
# 7                  3.0  11           3.0                    3.0           3.0
# 8                  1.0  11           1.0                    1.0           1.0
# 9                  1.0  11           3.0                    3.0           3.0
# 10                 1.0  11           1.0                    1.0           1.0
# 12                 3.0  11           3.0                    3.0           3.0
# 13                 3.0  11           3.0                    3.0           3.0
# 14                 1.0  11           3.0                    3.0           3.0
# 15                 3.0  11           3.0                    3.0           3.0
